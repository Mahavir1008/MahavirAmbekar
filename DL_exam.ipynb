# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data=pd.read_table("C:/Users/Mahavir/Desktop/DL/Faults.NNA.txt",header=None)

# %%
data.columns=['X_Minimum',
'X_Maximum',
'Y_Minimum',
'Y_Maximum',
'Pixels_Areas',
'X_Perimeter',
'Y_Perimeter',
'Sum_of_Luminosity',
'Minimum_of_Luminosity',
'Maximum_of_Luminosity',
'Length_of_Conveyer',
'TypeOfSteel_A300',
'TypeOfSteel_A400',
'Steel_Plate_Thickness',
'Edges_Index',
'Empty_Index',
'Square_Index',
'Outside_X_Index',
'Edges_X_Index',
'Edges_Y_Index',
'Outside_Global_Index',
'LogOfAreas',
'Log_X_Index',
'Log_Y_Index',
'Orientation_Index',
'Luminosity_Index',
'SigmoidOfAreas',
'Pastry',
'Z_Scratch',
'K_Scatch',
'Stains',
'Dirtiness',
'Bumps',
'Other_Faults']

# %%
data.shape
# Out:
# (1941, 34)

# %%
data.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity      ...       Orientation_Index  Luminosity_Index  \
# 0                    108      ...                  0.8182           -0.2913
# ...

# %%
np.random.seed(1234)

# %%
from sklearn.utils import shuffle

# %%
np.random.seed(12345)

# %%
d2=shuffle(data)

# %%
d2
# Out:
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 1927        160        170     252936     252958            97           24
# 1143        181        191     398801     398815           112           15
# 1217       1057       1084    3373856    3373874           168           44
# 645          39        214    2027555    2027621          6592          265
# 971          21         27    1988956    1988984           112           21
# 111        1245       1258     702370     702405           337           26
# 1866         50         72    2339660    2339663            51           22
# 149          62         74   12987661   12987692           258           27
# 1248        701        717    7156447    7156460           147           20
# 1108        950        957     852041     852053            63            9
# 1372       1137       1154    2265683    2265692            77           25
# ...

# %%
#np.random.shuffle(data)

# %%
#plt.plot(d2.Y_Maximum)

# %%
y=d2.filter(['Pastry',
'Z_Scratch',
'K_Scatch',
'Stains',
'Dirtiness',
'Bumps',
'Other_Faults'])

# %%
X=d2.filter(['X_Minimum',
'X_Maximum',
'Y_Minimum',
'Y_Maximum',
'Pixels_Areas',
'X_Perimeter',
'Y_Perimeter',
'Sum_of_Luminosity',
'Minimum_of_Luminosity',
'Maximum_of_Luminosity',
'Length_of_Conveyer',
'TypeOfSteel_A300',
'TypeOfSteel_A400',
'Steel_Plate_Thickness',
'Edges_Index',
'Empty_Index',
'Square_Index',
'Outside_X_Index',
'Edges_X_Index',
'Edges_Y_Index',
'Outside_Global_Index',
'LogOfAreas',
'Log_X_Index',
'Log_Y_Index',
'Orientation_Index',
'Luminosity_Index',
'SigmoidOfAreas'])

# %%
X_test=X.iloc[1841:,]

# %%
X_test.shape
# Out:
# (100, 27)

# %%
X_train=X.iloc[:1841,]

# %%
y_test=y.iloc[1841:,]
y_train=y.iloc[:1841,]

# %%
X_train.head()
# Out:
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 1927        160        170     252936     252958            97           24
# 1143        181        191     398801     398815           112           15
# 1217       1057       1084    3373856    3373874           168           44
# 645          39        214    2027555    2027621          6592          265
# 971          21         27    1988956    1988984           112           21
#
#       Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 1927           23              12775                    123
# 1143           14              11998                     87
# 1217           26              16835                     86
# 645           125             687299                     44
# 971            28              13196                    110
#
#       Maximum_of_Luminosity       ...        Outside_X_Index  Edges_X_Index  \
# ...

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train1 = sc.fit_transform(X_train)
X_test1 = sc.transform(X_test)

# %%
#X_train.info()

# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\Mahavir\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(output_dim = 14, init = 'uniform', activation = 'relu', input_dim = 27))

# Adding the input layer and the first hidden layer
#classifier.add(Dense(output_dim = 14, init = 'uniform', activation = 'relu')
# Adding the output layer
classifier.add(Dense(output_dim = 7, init = 'uniform', activation = 'softmax'))
# Out:
# C:\Users\Mahavir\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=27, units=14, kernel_initializer="uniform")`
#   """
# C:\Users\Mahavir\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="softmax", units=7, kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# ?classifier.compile
# Out:
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 1927        160        170     252936     252958            97           24
# 1143        181        191     398801     398815           112           15
# 1217       1057       1084    3373856    3373874           168           44
# 645          39        214    2027555    2027621          6592          265
# 971          21         27    1988956    1988984           112           21
# 111        1245       1258     702370     702405           337           26
# 1866         50         72    2339660    2339663            51           22
# 149          62         74   12987661   12987692           258           27
# 1248        701        717    7156447    7156460           147           20
# 1108        950        957     852041     852053            63            9
# 1372       1137       1154    2265683    2265692            77           25
# ...

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train1, y_train, batch_size = 200, nb_epoch = 500)
# Out:
# C:\Users\Mahavir\Anaconda3\lib\site-packages\keras\models.py:944: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/500
# 1841/1841 [==============================] - 2s 1ms/step - loss: 1.9403 - acc: 0.2439
# Epoch 2/500
# 1841/1841 [==============================] - 0s 54us/step - loss: 1.9187 - acc: 0.4324
# Epoch 3/500
# 1841/1841 [==============================] - 0s 55us/step - loss: 1.8863 - acc: 0.4758
# Epoch 4/500
# 1841/1841 [==============================] - 0s 55us/step - loss: 1.8375 - acc: 0.4851
# Epoch 5/500
# 1841/1841 [==============================] - 0s 55us/step - loss: 1.7685 - acc: 0.4916
# Epoch 6/500
# 1841/1841 [==============================] - 0s 54us/step - loss: 1.6866 - acc: 0.4965
# Epoch 7/500
# 1841/1841 [==============================] - 0s 52us/step - loss: 1.5958 - acc: 0.4948
# Epoch 8/500
# ...

# %%
X_train.head()
# Out:
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 1927        160        170     252936     252958            97           24
# 1143        181        191     398801     398815           112           15
# 1217       1057       1084    3373856    3373874           168           44
# 645          39        214    2027555    2027621          6592          265
# 971          21         27    1988956    1988984           112           21
#
#       Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 1927           23              12775                    123
# 1143           14              11998                     87
# 1217           26              16835                     86
# 645           125             687299                     44
# 971            28              13196                    110
#
#       Maximum_of_Luminosity       ...        Outside_X_Index  Edges_X_Index  \
# ...

# %%
# ?classifier.compile

# %%
y_pred = classifier.predict_classes(X_test1)

# %%
y_pred
# Out:
# array([0, 6, 5, 6, 2, 2, 2, 2, 1, 2, 5, 5, 6, 2, 1, 6, 6, 5, 2, 2, 5, 1,
#        2, 3, 6, 6, 6, 0, 5, 6, 5, 6, 0, 2, 6, 6, 5, 6, 6, 1, 0, 1, 0, 5,
#        2, 6, 6, 6, 0, 6, 2, 6, 2, 5, 5, 5, 3, 2, 2, 0, 4, 4, 2, 2, 0, 2,
#        5, 5, 0, 1, 0, 1, 1, 6, 0, 6, 6, 1, 2, 5, 5, 6, 3, 5, 6, 2, 6, 5,
#        6, 3, 5, 2, 6, 2, 5, 5, 0, 1, 6, 2], dtype=int64)

# %%
y_test.shape
# Out:
# (100, 7)

# %%
X_train.shape
# Out:
# (1841, 27)
